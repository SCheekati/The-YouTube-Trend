# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import scipy.stats as stats

trending = pd.read_csv('../dataset/output/dataset_mar_23/trending_data.csv')
nonTrending = pd.read_csv('../dataset/output/dataset_mar_23/nontrending_data.csv')
valdf = pd.read_csv('../dataset/output/dataset_mar_23/val.csv')


plt.boxplot([trending['views per day'], nonTrending['views per day']], notch=True, labels=['Trending', 'Nontrending'])
plt.yscale('log')
plt.show()

plt.boxplot([trending['rating'], nonTrending['rating']], notch=True, labels=['Trending', 'Nontrending'])
plt.yscale('log')
plt.show()
