# %%
import pandas as pd

# %%
nontrend = pd.read_csv('/Users/maykalnik/ML-7641-Team14-main/dataset/output/US_youtube_trending_data_0222_0313.csv')
trend = pd.read_csv('/Users/maykalnik/ML-7641-Team14-main/dataset/output/US_youtube_nontrending_data.csv')

# %%
print(nontrend['trending_date'].min())
print(trend['trending_date'].min())
# Out:
# 2022-12-24
# -1

# %% [markdown]
# ## That means do not change them again with pd datetotime

# %%
nontrend.head()
# Out:
#       video_id                                              title publishedAt  \
# 0  11yhaCoQskY  Will Ferrell Brings the Spirit to the Hot Ones...  2022-12-22
# 1  YzpPvMF3p9w  I Overloaded Hydroneer So Hard It Fully Shatte...  2022-12-22
# 2  oao_6QTCCiw                                      i got married  2022-12-22
# 3  RbMHHq4_hvI  EPISODE 1: THIS IS ME. (Overcomfort Podcast wi...  2022-12-22
# 4  bMME1Bg7Osc  Touch! Generations for Nintendo DS and Wii - S...  2022-12-23
#
#                   channelId       channelTitle  categoryId trending_date  \
# 0  UCPD_bxCRGpmmeQcbe2kpPaA     First We Feast          24    2022-12-24
# 1  UCto7D1L-MiRoOziCXK9uT5Q  Let's Game It Out          20    2022-12-24
# 2  UC_Z0x662N1VUN9J7FYwCwkg           julien 2          20    2022-12-24
# 3  UCMVoFmstUEDfDnGNuULsLZg      Jenicka Lopez          22    2022-12-24
# 4  UC4rqhyiTs7XyuODcECvuiiQ      Scott The Woz          20    2022-12-24
#
#                                                 tags  views per day  \
# 0  First we feast|fwf|firstwefeast|food|food porn...     714929.667
# 1  let's game it out|lets game it out|let game it...     545125.333
# 2  jenna|julien|julien solomita|jennajulien|julie...     314806.000
# 3  Jenicka Lopez|Jenicka|Lifestyle|New Video|Los ...      64979.000
# 4                                             [None]     235752.500
#
#    likes per day  dislikes per day  comments per day  \
# 0      26361.333            39.590          1321.667
# 1      30817.333            18.398          1639.667
# 2      45183.667            16.675          3452.000
# 3       4001.333           571.482           220.667
# 4      14627.000             2.378           866.500
#
#                                      thumbnail_link  rating  \
# 0  https://i.ytimg.com/vi/11yhaCoQskY/hqdefault.jpg   4.898
# 1  https://i.ytimg.com/vi/YzpPvMF3p9w/hqdefault.jpg   4.965
# 2  https://i.ytimg.com/vi/oao_6QTCCiw/hqdefault.jpg   4.974
# 3  https://i.ytimg.com/vi/RbMHHq4_hvI/hqdefault.jpg   2.154
# 4  https://i.ytimg.com/vi/bMME1Bg7Osc/hqdefault.jpg   4.981
#
#                                          description  trending
# 0  Will Ferrell is back—and so much more—for the ...         1
# 1  Ever seen a game reach 0.11 FPS? I HAVE, AND I...         1
# 2                                                NaN         1
# 3  In the latest episode of the Overcomfort Podca...         1
# 4  Touch, Scott! Touch!Limited Edition Merchandis...         1

# %%
print(nontrend.columns)
print(trend.columns)
print(len(trend.columns))
# Out:
# Index(['video_id', 'title', 'publishedAt', 'channelId', 'channelTitle',
#        'categoryId', 'trending_date', 'tags', 'views per day', 'likes per day',
#        'dislikes per day', 'comments per day', 'thumbnail_link', 'rating',
#        'description', 'trending'],
#       dtype='object')
# Index(['video_id', 'title', 'publishedAt', 'channelId', 'channelTitle',
#        'categoryId', 'trending_date', 'tags', 'views per day', 'likes per day',
#        'dislikes per day', 'comments per day', 'thumbnail_link', 'rating',
#        'description', 'trending'],
#       dtype='object')
# 16

# %%
df = pd.concat([nontrend, trend], ignore_index=True)

# %%
df
# Out:
#          video_id                                              title  \
# 0     11yhaCoQskY  Will Ferrell Brings the Spirit to the Hot Ones...
# 1     YzpPvMF3p9w  I Overloaded Hydroneer So Hard It Fully Shatte...
# 2     oao_6QTCCiw                                      i got married
# 3     RbMHHq4_hvI  EPISODE 1: THIS IS ME. (Overcomfort Podcast wi...
# 4     bMME1Bg7Osc  Touch! Generations for Nintendo DS and Wii - S...
# ...           ...                                                ...
# 4915  eAyG1kDs9E8                   35 SECRETS In Fortnite SEASON 2!
# 4916  7SUTGf4h6jE                  SIDEMEN TRY NOT TO MOVE CHALLENGE
# 4917  uOyUjpECWLE                          Quick analysis of Bedman?
# 4918  xwXM94kA3BM   Extreme Hide & Seek, But I Can't STOP Cheating..
# 4919  ji4uxn-jxfw  I duped 2,100,000,000 items in Survival Minecr...
#
#      publishedAt                 channelId       channelTitle  categoryId  \
# 0     2022-12-22  UCPD_bxCRGpmmeQcbe2kpPaA     First We Feast          24
# 1     2022-12-22  UCto7D1L-MiRoOziCXK9uT5Q  Let's Game It Out          20
# 2     2022-12-22  UC_Z0x662N1VUN9J7FYwCwkg           julien 2          20
# 3     2022-12-22  UCMVoFmstUEDfDnGNuULsLZg      Jenicka Lopez          22
# 4     2022-12-23  UC4rqhyiTs7XyuODcECvuiiQ      Scott The Woz          20
# ...          ...                       ...                ...         ...
# 4915  2023-03-11  UCYn6CZe5UGIyPe9WJb0pTrg         Top5Gaming          20
# 4916  2023-03-12  UCDogdKl7t7NHzQ95aEwkdMw            Sidemen          24
# 4917  2023-03-12  UCzsrOrAsqomJUhUUI8Nxckw            Mr. Unc          20
# 4918  2023-03-15  UCilwZiBBfI9X6yiZRzWty8Q           FaZe Rug          24
# 4919  2023-03-15  UCk2uxbWi5py_iJXaEsh2YRA              Spoke          20
#
#      trending_date                                               tags  \
# 0       2022-12-24  First we feast|fwf|firstwefeast|food|food porn...
# 1       2022-12-24  let's game it out|lets game it out|let game it...
# 2       2022-12-24  jenna|julien|julien solomita|jennajulien|julie...
# 3       2022-12-24  Jenicka Lopez|Jenicka|Lifestyle|New Video|Los ...
# 4       2022-12-24                                             [None]
# ...            ...                                                ...
# 4915            -1  fortnite season 2|35 SECRETS In Fortnite SEASO...
# 4916            -1              sidemen|sidemen sunday|#sidemensunday
# 4917            -1  Guilty Gear Strive|Bedman?|Bedman|Meme|Guide|A...
# 4918            -1                       faze rug|rug|rugfaze|fazerug
# 4919            -1     spoke|spokeishere|lifesteal|minecraft|survival
#
#       views per day  likes per day  dislikes per day  comments per day  \
# 0        714929.667      26361.333            39.590          1321.667
# 1        545125.333      30817.333            18.398          1639.667
# 2        314806.000      45183.667            16.675          3452.000
# 3         64979.000       4001.333           571.482           220.667
# 4        235752.500      14627.000             2.378           866.500
# ...             ...            ...               ...               ...
# 4915     225641.500       5057.667           102.000           213.833
# 4916    1374928.800      78917.800          1019.200          2380.200
# 4917       5707.200        183.200             2.400            27.800
# 4918     565901.500      24922.500           391.500          3204.500
# 4919     146801.500       5849.000           107.000           353.000
#
#                                         thumbnail_link  rating  \
# 0     https://i.ytimg.com/vi/11yhaCoQskY/hqdefault.jpg   4.898
# 1     https://i.ytimg.com/vi/YzpPvMF3p9w/hqdefault.jpg   4.965
# 2     https://i.ytimg.com/vi/oao_6QTCCiw/hqdefault.jpg   4.974
# 3     https://i.ytimg.com/vi/RbMHHq4_hvI/hqdefault.jpg   2.154
# 4     https://i.ytimg.com/vi/bMME1Bg7Osc/hqdefault.jpg   4.981
# ...                                                ...     ...
# 4915  https://i.ytimg.com/vi/eAyG1kDs9E8/hqdefault.jpg   4.921
# 4916  https://i.ytimg.com/vi/7SUTGf4h6jE/hqdefault.jpg   4.949
# 4917  https://i.ytimg.com/vi/uOyUjpECWLE/hqdefault.jpg   4.948
# 4918  https://i.ytimg.com/vi/xwXM94kA3BM/hqdefault.jpg   4.938
# 4919  https://i.ytimg.com/vi/ji4uxn-jxfw/hqdefault.jpg   4.928
#
#                                             description  trending
# 0     Will Ferrell is back—and so much more—for the ...         1
# 1     Ever seen a game reach 0.11 FPS? I HAVE, AND I...         1
# 2                                                   NaN         1
# 3     In the latest episode of the Overcomfort Podca...         1
# 4     Touch, Scott! Touch!Limited Edition Merchandis...         1
# ...                                                 ...       ...
# 4915  35 SECRETS In Fortnite SEASON 2!Item Shop Code...         0
# 4916  If you really want to see it: https://watch.si...         0
# 4917  No Hemijack? We riot. JK, I'll hold off on the...         0
# 4918  Another hide & seek, another time for me to ch...         0
# 4919  I found another dupe on lifesteal lol except t...         0
#
# [4920 rows x 16 columns]

# %%
#df.to_csv('C:\\Users\\cheek\\ML-7641-Team14\\dataset\\output\\combined.csv', index=False)

# %%
import matplotlib.pyplot as plt

# %%
df['trending'].value_counts().plot(kind='bar')
plt.show()

# %%
trend['trending_date'] = pd.to_datetime(trend['trending_date'], format='%Y-%m-%d')
trend['publishedAt'] = pd.to_datetime(trend['publishedAt'], format='%Y-%m-%d')

views_by_date = trend.groupby('trending_date')['views per day'].mean()
plt.plot(views_by_date.index, views_by_date.values)
plt.title('Trend of Views per Day for Trending Videos')
plt.xlabel('Trending Date')
plt.ylabel('Views per Day')
plt.show()

# %%
grouped = trend.groupby('trending_date').mean()
dates = grouped.index

plt.plot(dates, grouped['views per day'], label='Views per Day')
plt.plot(dates, grouped['likes per day'], label='Likes per Day')
plt.plot(dates, grouped['dislikes per day'], label='Dislikes per Day')
plt.plot(dates, grouped['comments per day'], label='Comments per Day')
plt.title('Trend of Engagement Metrics per Day for Trending and Non-trending Videos')
plt.xlabel('Date')
plt.ylabel('Metric Value')
plt.legend()
plt.show()
# Out:
# C:\Users\cheek\AppData\Local\Temp\ipykernel_15404\334195312.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped = trend.groupby('trending_date').mean()

# %%
print(trend['trending_date'].min())
# Out:
# 1969-12-31 23:59:59.999999999

# %%
# tesing sklearn
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
X = np.array([[-1, -1], [-2, -1], [1, 1], [2, 1]])
print(np.shape(X))
y = np.array([1, 1, 2, 2])
print(np.shape(y))
from sklearn.svm import SVC
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(X, y)
Pipeline(steps=[('standardscaler', StandardScaler()),
                ('svc', SVC(gamma='auto'))])


print(clf.predict([[-0.8, -1]]))
# Out:
# (4, 2)
# (4,)
# [1]

# %%
# The View Column
X = df['views per day'].to_numpy().reshape(-1,1)
# Trending Label
y = df['trending'].to_numpy()
print(np.shape(X))
print(np.shape(y))

clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(X, y)
Pipeline(steps=[('standardscaler', StandardScaler()),
                ('svc', SVC(gamma='auto'))])

testVideo = [df.to_numpy()[-1, 8]]
actual = [df.to_numpy()[-1, -1]]
predicted =  clf.predict([testVideo])
print("actual: ", actual)
print("predicted; ", predicted)
# Out:
# (4920, 1)
# (4920,)
# actual:  [0]
# predicted;  [1]

# %%
#non trending
points = df.to_numpy()[np.where(y == 0)[0]]
plt.plot(points[:, 8], points[:, -1],'x', color="blue", label = 'trending')

#trending
points = df.to_numpy()[np.where(y == 1)[0]]
plt.plot(points[:, 8], points[:, -1],'x', color="red", label = 'non trending')

#testing
plt.plot([testVideo, testVideo], [actual, predicted],'x', color="black", label = 'testing')

plt.legend()

# %%
features = [8,9,10,11,13]
for i in range (len(features)):
    #non trending
    points = df.to_numpy()[np.where(y == 0)[0]]
    plt.plot(points[:, features[i]], points[:, -1],'o', color="blue", label = 'trending')

    #trending
    points = df.to_numpy()[np.where(y == 1)[0]]
    plt.plot(points[:, features[i]], points[:, -1],'o', color="red", label = 'non trending')

    #testing
    plt.plot([df.to_numpy()[-1, features[i]], df.to_numpy()[-1, features[i]]], [actual, predicted],'o', color="black", label = 'testing')
    
    plt.title(df.columns[features[i]])
    plt.legend()
    plt.show()

# %%
#all features
X = df[['views per day','likes per day', 'dislikes per day', 'comments per day', 'rating']].to_numpy()
Y = df['trending'].to_numpy()

# all features, minus last data point
trainingX = X[:-1]
trainingY = Y[:-1]

clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(trainingX, trainingY)
Pipeline(steps=[('standardscaler', StandardScaler()),('svc', SVC(gamma='auto'))])

testVideo = X[-1]
testVideoActual = Y[-1]
testVideoPred =  clf.predict([testVideo])
print("actual: ", actual)
print("predicted; ", predicted)
# Out:
# actual:  [0]
# predicted;  [0]

# %%
features = [8,9,10,11,13]
for i in range (len(features)):
    #non trending
    points = df.to_numpy()[np.where(y == 0)[0]]
    plt.plot(points[:, features[i]], points[:, -1],'o', color="blue", label = 'trending')

    #trending
    points = df.to_numpy()[np.where(y == 1)[0]]
    plt.plot(points[:, features[i]], points[:, -1],'o', color="red", label = 'non trending')

    #testing
    plt.plot([testVideo[i], testVideo[i]], [testVideoActual, testVideoPred],'o', color="black", label = 'testing')
    
    plt.title(df.columns[features[i]])
    plt.xlabel(df.columns[features[i]])
    plt.ylabel("trending or not")
    plt.legend()
    plt.show()
# Out:
# /Users/maykalnik/opt/anaconda3/envs/MachineLearning/lib/python3.9/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
